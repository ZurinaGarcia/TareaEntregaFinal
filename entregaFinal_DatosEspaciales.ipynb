# %%
from  fiona import listlayers
import os

ukraineMaps=os.path.join('maps','ukraineMaps_all.gpkg')

#layers in maps
listlayers(ukraineMaps)
# Out:
# ['country',
#  'cities',
#  'rivers',
#  'airports',
#  'border',
#  'municipalities',
#  'states',
#  'seaports']

# %%
#Exercise 1
#Use two maps of points.

#Compute the distance matrix for both maps.

#Select one row of the distance matrix, and plot the two points with the minimal distance on top of the country of your choosing.

# %%
import geopandas as gpd
import pandas as pd
import os
airports=gpd.read_file(ukraineMaps,layer='airports')
rivers=gpd.read_file(ukraineMaps,layer='rivers')
seaports=gpd.read_file(ukraineMaps,layer='seaports')

# %%
airports
# Out:
#                                                   name            type  \
# 0                       Boryspil International Airport   large_airport
# 1    Ihor Sikorsky Kyiv International Airport (Zhul...  medium_airport
# 2                         Odessa International Airport  medium_airport
# 3                           Lviv International Airport   large_airport
# 4                     Simferopol International Airport  medium_airport
# ..                                                 ...             ...
# 247                                   Oreanda Heliport        heliport
# 248                           Pension Wisteria Helipad        heliport
# 249                          Massandra Palace Heliport        heliport
# 250                                     Artek Heliport        heliport
# 251                                   Palmira Airfield          closed
#
#      latitude_deg  longitude_deg  elevation_ft                   region_name  \
# 0       50.345001      30.894699         427.0                   Kyiv Oblast
# 1       50.401940      30.451940         587.0                   Kyiv (city)
# 2       46.426800      30.676500         172.0                 Odessa Oblast
# 3       49.812500      23.956100        1071.0                   Lviv Oblast
# 4       45.052200      33.975101         639.0  Crimea (Autonomous Republic)
# ..            ...            ...           ...                           ...
# 247     44.451300      34.129300         479.0  Crimea (Autonomous Republic)
# 248     44.461824      34.145346         125.0  Crimea (Autonomous Republic)
# 249     44.514500      34.203900         971.0  Crimea (Autonomous Republic)
# 250     44.560590      34.307563         335.0  Crimea (Autonomous Republic)
# 251     49.763000      32.123000           NaN               Cherkasy Oblast
#
#     municipality                           geometry
# 0       Boryspil  POINT (13220942.772 16469406.144)
# 1           Kyiv  POINT (13171684.889 16479311.223)
# 2         Odessa  POINT (13196667.668 15814518.993)
# 3           Lviv  POINT (12449008.843 16377345.080)
# 4     Simferopol  POINT (13563644.060 15596101.657)
# ..           ...                                ...
# 247        Yalta  POINT (13580799.028 15502284.070)
# 248        Yalta  POINT (13582584.179 15503918.759)
# 249        Yalta  POINT (13589098.437 15512105.365)
# 250        Yalta  POINT (13600631.166 15519274.526)
# 251  Zolotonosha  POINT (13357593.876 16368839.231)
#
# [252 rows x 8 columns]

# %%
# seleccionamos el subconjunto de los aeropuertos medianos
mediumAirports=airports[airports['type']=='medium_airport']
mediumAirports.reset_index(drop=True, inplace=True)

#ploteamos
base=mediumAirports.plot(color='red',marker="^")
seaports.plot(ax=base,alpha=0.5,markersize=3)
# Out:
# <Axes: >

# %%
seaports
# Out:
#                 portName Country Code   Latitude  Longitude  \
# 0              Kyrylivka      Ukraine  46.350000  35.366667
# 1              Henichesk      Ukraine  46.166667  34.816667
# 2              Balaklava      Ukraine  44.500000  33.600000
# 3                Alushta      Ukraine  44.683333  34.416667
# 4                  Sudak      Ukraine  44.850000  34.983333
# 5            Ust-Dunaisk      Ukraine  45.466667  29.700000
# 6               Mariupol      Ukraine  47.083333  37.566667
# 7              Berdyansk      Ukraine  46.750000  36.783333
# 8              Mykolayiv      Ukraine  46.950000  31.983333
# 9                Izmayil      Ukraine  45.333333  28.850000
# 10                  Reni      Ukraine  45.433333  28.300000
# 11               Kherson      Ukraine  46.616667  32.600000
# 12                 Odesa      Ukraine  46.483333  30.733333
# 13         Dnipro-Buzkyy      Ukraine  46.733333  31.883333
# 14                Khorly      Ukraine  46.083333  33.283333
# 15         Chornomors Ke      Ukraine  45.516667  32.700000
# 16                 Kerch      Ukraine  45.350000  36.483333
# 17             Feodosiya      Ukraine  45.016667  35.433333
# 18            Illichivsk      Ukraine  46.300000  30.650000
# 19  Belgorod-Dnestrovsky      Ukraine  46.183333  30.366667
# 20        Port Oktyabrsk      Ukraine  46.833333  31.933333
# 21           Yevpatoriya      Ukraine  45.200000  33.383333
# 22                 Yalta      Ukraine  44.483333  34.166667
# 23               Yuzhnyy      Ukraine  46.600000  31.016667
# 24             Skadovs'k      Ukraine  46.100000  32.916667
# 25            Sevastopol      Ukraine  44.616667  33.533333
#
#                              geometry
# 0   POINT (13718458.744 15802171.538)
# 1   POINT (13657270.072 15772766.738)
# 2   POINT (13521913.274 15509851.114)
# 3   POINT (13612769.219 15538394.769)
# 4   POINT (13675812.019 15564422.666)
# 5   POINT (13088029.962 15661391.224)
# 6   POINT (13963213.433 15920795.003)
# 7   POINT (13876065.856 15866674.045)
# 8   POINT (13342055.625 15899105.975)
# 9   POINT (12993465.650 15640335.164)
# 10  POINT (12932276.977 15656122.438)
# 11  POINT (13410661.143 15845120.046)
# 12  POINT (13202990.460 15823619.229)
# 13  POINT (13330930.412 15863976.804)
# 14  POINT (13486683.396 15759433.397)
# 15  POINT (13421786.356 15669300.129)
# 16  POINT (13842690.217 15642964.478)
# 17  POINT (13725875.478 15590526.499)
# 18  POINT (13193719.486 15794142.212)
# 19  POINT (13162198.086 15775435.716)
# 20  POINT (13336493.018 15880172.531)
# 21  POINT (13497808.609 15619329.104)
# 22  POINT (13584956.186 15507260.667)
# 23  POINT (13234511.972 15842429.495)
# 24  POINT (13445891.022 15762098.474)
# 25  POINT (13514496.429 15528004.850)

# %%
seaports.head()
# Out:
#     portName Country Code   Latitude  Longitude  \
# 0  Kyrylivka      Ukraine  46.350000  35.366667
# 1  Henichesk      Ukraine  46.166667  34.816667
# 2  Balaklava      Ukraine  44.500000  33.600000
# 3    Alushta      Ukraine  44.683333  34.416667
# 4      Sudak      Ukraine  44.850000  34.983333
#
#                             geometry
# 0  POINT (13718458.744 15802171.538)
# 1  POINT (13657270.072 15772766.738)
# 2  POINT (13521913.274 15509851.114)
# 3  POINT (13612769.219 15538394.769)
# 4  POINT (13675812.019 15564422.666)

# %%
mediumAirports.head()
# Out:
#                                                 name            type  \
# 0  Ihor Sikorsky Kyiv International Airport (Zhul...  medium_airport
# 1                       Odessa International Airport  medium_airport
# 2                   Simferopol International Airport  medium_airport
# 3                      Kharkiv International Airport  medium_airport
# 4                       Dnipro International Airport  medium_airport
#
#    latitude_deg  longitude_deg  elevation_ft  \
# 0     50.401940      30.451940         587.0
# 1     46.426800      30.676500         172.0
# 2     45.052200      33.975101         639.0
# 3     49.924801      36.290001         508.0
# 4     48.357201      35.100601         481.0
#
#                          region_name municipality  \
# 0                        Kyiv (city)         Kyiv
# 1                      Odessa Oblast       Odessa
# 2       Crimea (Autonomous Republic)   Simferopol
# 3                     Kharkiv Oblast      Kharkiv
# 4  Dnipropetrovsk (Sicheslav) Oblast       Dnipro
#
#                             geometry
# 0  POINT (13171684.889 16479311.223)
# 1  POINT (13196667.668 15814518.993)
# 2  POINT (13563644.060 15596101.657)
# 3  POINT (13821181.619 16396674.851)
# 4  POINT (13688858.334 16130827.518)

# %%
distanceMatrixKM_sea_air= seaports.set_index('portName').geometry.apply\
                          (lambda g: mediumAirports.set_index('name').geometry.distance(g)/1000).\
                          sort_index(axis=0).sort_index(axis=1)

# %%
distanceMatrixKM_sea_air.mean(axis=1).sort_values(ascending=True)
# Out:
# portName
# Mykolayiv               483.694396
# Port Oktyabrsk          487.477924
# Kherson                 490.802678
# Dnipro-Buzkyy           491.369217
# Yuzhnyy                 514.585329
# Skadovs'k               515.027035
# Khorly                  518.975658
# Odesa                   527.531054
# Illichivsk              539.705706
# Chornomors Ke           550.838869
# Belgorod-Dnestrovsky    557.049981
# Henichesk               566.356492
# Yevpatoriya             572.962940
# Kyrylivka               592.325425
# Sevastopol              632.895650
# Ust-Dunaisk             635.212412
# Balaklava               648.906133
# Alushta                 652.677956
# Sudak                   664.260698
# Yalta                   666.521120
# Feodosiya               676.749684
# Izmayil                 686.568227
# Berdyansk               688.139327
# Reni                    709.319420
# Kerch                   729.751191
# Mariupol                750.952684
# dtype: float64

# %%
# puerto marítimo más cercano a cada aeropuerto mediano
distanceMatrixKM_sea_air.idxmin(axis="rows")
# Out:
# name
# Bila Tserkva Air Base                                    Mykolayiv
# Cherkasy International Airport                           Mykolayiv
# Chernivtsi International Airport                              Reni
# Dnipro International Airport                             Berdyansk
# Dolgintsevo Air Base                                     Mykolayiv
# Dzhankoy Airport                                         Henichesk
# Gvardeyskoe Air Base                                   Yevpatoriya
# Hostomel Airport                                         Mykolayiv
# Ihor Sikorsky Kyiv International Airport (Zhuliany)      Mykolayiv
# Ivano-Frankivsk International Airport                         Reni
# Kacha Air Base                                          Sevastopol
# Kharkiv International Airport                             Mariupol
# Kherson International Airport                              Kherson
# Khmelnytskyi Airport                                         Odesa
# Kirovskoe Air Base                                       Feodosiya
# Kryvyi Rih International Airport                         Mykolayiv
# Mariupol International Airport                            Mariupol
# Melitopol Air Base                                       Kyrylivka
# Mykolaiv International Airport                           Mykolayiv
# Nizhyn Air Base                                          Mykolayiv
# Odessa International Airport                                 Odesa
# Oktyabrskoe Air Base                                   Yevpatoriya
# Ozerne Air Base                                            Yuzhnyy
# Rivne International Airport                                  Odesa
# Saky Air Base                                          Yevpatoriya
# Sevastopol International Airport / Belbek Air Base      Sevastopol
# Simferopol International Airport                       Yevpatoriya
# Uzhhorod International Airport                                Reni
# Vinnytsia/Gavyryshivka International Airport               Yuzhnyy
# Zaporizhzhia International Airport                       Berdyansk
# Zhovtneve Air Base                                         Izmayil
# dtype: object

# %%
mediumAirports.rename(columns={'name':'Aeropuertos_medianos'},inplace=True)
# Out:
# C:\Users\Zurina\AppData\Local\Temp\ipykernel_1744\2920383029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mediumAirports.rename(columns={'name':'Aeropuertos_medianos'},inplace=True)

# %%
#plot con un aeropuerto mediano y puerto marítimo seleccionado (ambos con distancias mínimas)
base=mediumAirports[mediumAirports.Aeropuertos_medianos=='Bila Tserkva Air Base'].plot(color='blue',marker="+")
seaports[seaports.portName=='Mykolayiv'].plot(ax=base,alpha=1,markersize=3,color='red',marker="*")
# Out:
# <Axes: >

# %%
################### EJERCICIO 2 ####################################################

# %%
#Exercise 2
#Use a map of points and a map of lines.

#Compute the distance matrix for both maps.

#Select one line of the distance matrix, and plot the closests and the farthest point to that line.

# %%
rivers
# Out:
#       NAME  SYSTEM                                           geometry
# 0     Amur     NaN  MULTILINESTRING ((14241462.452 16326582.942, 1...
# 1   Danube     NaN  MULTILINESTRING ((12925279.899 15658032.359, 1...
# 2  Dnieper     NaN  LINESTRING (13227369.160 16775728.086, 1323925...

# %%
rivers.rename(columns={'NAME':'Rivers_name'},inplace=True)
#vemos la lista de los ríos
rivers['Rivers_name'].values.tolist()
# Out:
# ['Amur', 'Danube', 'Dnieper']

# %%
#distancia entre el río Amur y los aeropuertos medianos
rivers[rivers.Rivers_name.str.contains('Amur')].iloc[0].geometry.distance(mediumAirports.geometry)
# Out:
# 0      41801.286530
# 1     512829.360766
# 2     730977.745254
# 3      12564.465314
# 4     196160.280043
# 5     157093.814789
# 6     277579.107183
# 7     213230.452509
# 8     108575.299290
# 9      76864.673033
# 10     17853.133705
# 11    638673.038408
# 12    787393.386524
# 13     47588.561907
# 14    248552.139618
# 15     75996.608398
# 16    472526.586315
# 17    407179.329594
# 18    410593.537648
# 19      8861.993474
# 20    628540.115748
# 21    773667.333904
# 22     27792.599114
# 23    712843.225258
# 24    274417.180204
# 25    439229.939464
# 26    162718.930650
# 27    724977.801743
# 28    688836.912213
# 29    720928.423305
# 30      1132.449175
# Name: geometry, dtype: float64

# %%
#guardamos la matriz de la distancia entre ríos y aeropuertos medianos
distanceMatrixKM_riv_air=rivers.set_index('Rivers_name').geometry.apply\
(lambda g: mediumAirports.set_index('Aeropuertos_medianos').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)
distanceMatrixKM_riv_air
# Out:
# Aeropuertos_medianos  Bila Tserkva Air Base  Cherkasy International Airport  \
# Rivers_name
# Amur                               8.861993                       17.853134
# Danube                           729.685463                      732.297573
# Dnieper                          130.468122                       32.834149
#
# Aeropuertos_medianos  Chernivtsi International Airport  \
# Rivers_name
# Amur                                        213.230453
# Danube                                      518.821909
# Dnieper                                     647.901761
#
# Aeropuertos_medianos  Dnipro International Airport  Dolgintsevo Air Base  \
# Rivers_name
# Amur                                    196.160280            274.417180
# Danube                                  785.576051            604.431618
# Dnieper                                  23.876637             83.865914
#
# Aeropuertos_medianos  Dzhankoy Airport  Gvardeyskoe Air Base  \
# Rivers_name
# Amur                        628.540116            720.928423
# Danube                      528.449744            473.996184
# Dnieper                     204.419900            279.260750
#
# Aeropuertos_medianos  Hostomel Airport  \
# Rivers_name
# Amur                         76.864673
# Danube                      870.345222
# Dnieper                      62.531831
#
# Aeropuertos_medianos  Ihor Sikorsky Kyiv International Airport (Zhuliany)  \
# Rivers_name
# Amur                                                          41.801287
# Danube                                                       843.158521
# Dnieper                                                       43.664201
#
# Aeropuertos_medianos  Ivano-Frankivsk International Airport  ...  \
# Rivers_name                                                  ...
# Amur                                             108.575299  ...
# Danube                                           684.449483  ...
# Dnieper                                          732.576930  ...
#
# Aeropuertos_medianos  Oktyabrskoe Air Base  Ozerne Air Base  \
# Rivers_name
# Amur                            688.836912         1.132449
# Danube                          487.707445       772.220780
# Dnieper                         252.158951       238.767084
#
# Aeropuertos_medianos  Rivne International Airport  Saky Air Base  \
# Rivers_name
# Amur                                    75.996608     724.977802
# Danube                                 885.681503     432.128562
# Dnieper                                505.557078     271.617037
#
# Aeropuertos_medianos  Sevastopol International Airport / Belbek Air Base  \
# Rivers_name
# Amur                                                         787.393387
# Danube                                                       436.871850
# Dnieper                                                      330.921028
#
# Aeropuertos_medianos  Simferopol International Airport  \
# Rivers_name
# Amur                                        730.977745
# Danube                                      474.275405
# Dnieper                                     288.880090
#
# Aeropuertos_medianos  Uzhhorod International Airport  \
# Rivers_name
# Amur                                      157.093815
# Danube                                    842.186924
# Dnieper                                  1002.104825
#
# Aeropuertos_medianos  Vinnytsia/Gavyryshivka International Airport  \
# Rivers_name
# Amur                                                     47.588562
# Danube                                                  614.775941
# Dnieper                                                 312.363042
#
# Aeropuertos_medianos  Zaporizhzhia International Airport  Zhovtneve Air Base
# Rivers_name
# Amur                                          277.579107          638.673038
# Danube                                        755.092623           31.983742
# Dnieper                                         0.760716          441.779165
#
# [3 rows x 31 columns]

# %%
# distancia entre el río seleccionado y cada aeropuerto mediano ordenado ascendentemente
distanceMatrixKM_riv_air.loc['Amur'].sort_values()
# Out:
# Aeropuertos_medianos
# Ozerne Air Base                                          1.132449
# Bila Tserkva Air Base                                    8.861993
# Kharkiv International Airport                           12.564465
# Cherkasy International Airport                          17.853134
# Khmelnytskyi Airport                                    27.792599
# Ihor Sikorsky Kyiv International Airport (Zhuliany)     41.801287
# Vinnytsia/Gavyryshivka International Airport            47.588562
# Rivne International Airport                             75.996608
# Hostomel Airport                                        76.864673
# Ivano-Frankivsk International Airport                  108.575299
# Uzhhorod International Airport                         157.093815
# Nizhyn Air Base                                        162.718931
# Dnipro International Airport                           196.160280
# Chernivtsi International Airport                       213.230453
# Kryvyi Rih International Airport                       248.552140
# Dolgintsevo Air Base                                   274.417180
# Zaporizhzhia International Airport                     277.579107
# Mariupol International Airport                         407.179330
# Mykolaiv International Airport                         410.593538
# Melitopol Air Base                                     439.229939
# Kherson International Airport                          472.526586
# Odessa International Airport                           512.829361
# Dzhankoy Airport                                       628.540116
# Zhovtneve Air Base                                     638.673038
# Oktyabrskoe Air Base                                   688.836912
# Kirovskoe Air Base                                     712.843225
# Gvardeyskoe Air Base                                   720.928423
# Saky Air Base                                          724.977802
# Simferopol International Airport                       730.977745
# Kacha Air Base                                         773.667334
# Sevastopol International Airport / Belbek Air Base     787.393387
# Name: Amur, dtype: float64

# %%
#seleccionamos solo una fila de nuestra matriz
fila2=distanceMatrixKM_riv_air.iloc[[1]]
fila2
# Out:
# Aeropuertos_medianos  Bila Tserkva Air Base  Cherkasy International Airport  \
# Rivers_name
# Danube                           729.685463                      732.297573
#
# Aeropuertos_medianos  Chernivtsi International Airport  \
# Rivers_name
# Danube                                      518.821909
#
# Aeropuertos_medianos  Dnipro International Airport  Dolgintsevo Air Base  \
# Rivers_name
# Danube                                  785.576051            604.431618
#
# Aeropuertos_medianos  Dzhankoy Airport  Gvardeyskoe Air Base  \
# Rivers_name
# Danube                      528.449744            473.996184
#
# Aeropuertos_medianos  Hostomel Airport  \
# Rivers_name
# Danube                      870.345222
#
# Aeropuertos_medianos  Ihor Sikorsky Kyiv International Airport (Zhuliany)  \
# Rivers_name
# Danube                                                       843.158521
#
# Aeropuertos_medianos  Ivano-Frankivsk International Airport  ...  \
# Rivers_name                                                  ...
# Danube                                           684.449483  ...
#
# Aeropuertos_medianos  Oktyabrskoe Air Base  Ozerne Air Base  \
# Rivers_name
# Danube                          487.707445        772.22078
#
# Aeropuertos_medianos  Rivne International Airport  Saky Air Base  \
# Rivers_name
# Danube                                 885.681503     432.128562
#
# Aeropuertos_medianos  Sevastopol International Airport / Belbek Air Base  \
# Rivers_name
# Danube                                                        436.87185
#
# Aeropuertos_medianos  Simferopol International Airport  \
# Rivers_name
# Danube                                      474.275405
#
# Aeropuertos_medianos  Uzhhorod International Airport  \
# Rivers_name
# Danube                                    842.186924
#
# Aeropuertos_medianos  Vinnytsia/Gavyryshivka International Airport  \
# Rivers_name
# Danube                                                  614.775941
#
# Aeropuertos_medianos  Zaporizhzhia International Airport  Zhovtneve Air Base
# Rivers_name
# Danube                                        755.092623           31.983742
#
# [1 rows x 31 columns]

# %%
#aeropuerto mediano más cercano a río
minsDanube=fila2.idxmin(axis="columns")
minsDanube
# Out:
# Rivers_name
# Danube    Zhovtneve Air Base
# dtype: object

# %%
maxDanube=fila2.idxmax(axis="columns")
maxDanube
# Out:
# Rivers_name
# Danube    Kharkiv International Airport
# dtype: object

# %%
#creamos el mapa iterativo de la cuenca Yukon y el aeropuerto mediano más cercano y lejano
base=rivers[rivers.Rivers_name.str.contains('Danube')].explore()
#aeropuertos medianos más cercanos
mediumAirports[mediumAirports.Aeropuertos_medianos.isin(minsDanube)].explore(m=base,color='purple',marker_kwds=dict(radius=10))
# aeropuertos medianos más lejanos
mediumAirports[mediumAirports.Aeropuertos_medianos.isin(maxDanube)].explore(m=base,color='green',marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0006ade7a64824f9321c2497fccdd4f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0006ade7a64824f9321c2497fccdd4f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0006ade7a64824f9321c2497fccdd4f4 = L.map(
#                 &quot;map_0006ade7a64824f9321c2497fccdd4f4&quot;,
#                 {
#                     center: [45.355249085614545, 28.97782187664763],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0006ade7a64824f9321c2497fccdd4f4);
#
#
#
#
#
#             var tile_layer_f4f17f55b47d8e831278b5a00cf07d25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0006ade7a64824f9321c2497fccdd4f4);
#
#
#             map_0006ade7a64824f9321c2497fccdd4f4.fitBounds(
#                 [[45.21882184066266, 28.237106115289457], [45.49167633056642, 29.718537638005802]],
#                 {}
#             );
#
#
#         function geo_json_5e46faa5148f2b739c7d26679a9558ec_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5e46faa5148f2b739c7d26679a9558ec_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5e46faa5148f2b739c7d26679a9558ec_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5e46faa5148f2b739c7d26679a9558ec_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5e46faa5148f2b739c7d26679a9558ec_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5e46faa5148f2b739c7d26679a9558ec.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5e46faa5148f2b739c7d26679a9558ec_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5e46faa5148f2b739c7d26679a9558ec = L.geoJson(null, {
#                 onEachFeature: geo_json_5e46faa5148f2b739c7d26679a9558ec_onEachFeature,

# %%
################################ EJERCICIO 3 ########################################################

# %%
#Exercise 3
#Create a set of points and a set of polygons

#Compute the distance matrix for both sets.

#Select one polygon of the distance matrix, and plot the closests and the farthest point to that polygon.

# %%
rivers.convex_hull.plot()
# Out:
# <Axes: >

# %%
#creamos un data frame con la geometría de los convex hull
rivers_hulls=rivers.convex_hull.to_frame()
#creamos una nueva columna y asignamos los nombres de cada cuenca
rivers_hulls['Rivers_name']=['Amur', 'Danube', 'Dnieper']
#renombramos
rivers_hulls.rename(columns={0:'geometry'},inplace=True)
#geometry pasa a ser de tipo GeoSeries
rivers_hulls=rivers_hulls.set_geometry('geometry')
#asignamos el crs
rivers_hulls.crs="EPSG:1242"
rivers_hulls
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[28], line 10
#       8 rivers_hulls=rivers_hulls.set_geometry('geometry')
#       9 #asignamos el crs
# ---> 10 rivers_hulls.crs="EPSG:1242"
#      11 rivers_hulls
#
# File ~\anaconda3\envs\Special_20206484_ZG\Lib\site-packages\geopandas\geodataframe.py:206, in GeoDataFrame.__setattr__(self, attr, val)
#     204     object.__setattr__(self, attr, val)
#     205 else:
# --> 206     super().__setattr__(attr, val)
#
# File ~\anaconda3\envs\Special_20206484_ZG\Lib\site-packages\pandas\core\generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~\anaconda3\envs\Special_20206484_ZG\Lib\site-packages\geopandas\geodataframe.py:456, in GeoDataFrame.crs(self, value)
#     449     raise ValueError(
#     450         "Assigning CRS to a GeoDataFrame without a geometry column is not "
#     451         "supported. Use GeoDataFrame.set_geometry to set the active "
#     452         "geometry column.",
#     453     )
#     455 if hasattr(self.geometry.values, "crs"):
# --> 456     self.geometry.values.crs = value
#     457 else:
#     458     # column called 'geometry' without geometry
#     459     raise ValueError(
#     460         "Assigning CRS to a GeoDataFrame without an active geometry "
#     461         "column is not supported. Use GeoDataFrame.set_geometry to set "
#     462         "the active geometry column.",
#     463     )
#
# File ~\anaconda3\envs\Special_20206484_ZG\Lib\site-packages\geopandas\array.py:360, in GeometryArray.crs(self, value)
#     357 @crs.setter
#     358 def crs(self, value):
#     359     """Sets the value of the crs"""
# --> 360     self._crs = None if not value else CRS.from_user_input(value)
#
# File ~\anaconda3\envs\Special_20206484_ZG\Lib\site-packages\pyproj\crs\crs.py:501, in CRS.from_user_input(cls, value, **kwargs)
#     499 if isinstance(value, cls):
#     500     return value
# --> 501 return cls(value, **kwargs)
#
# File ~\anaconda3\envs\Special_20206484_ZG\Lib\site-packages\pyproj\crs\crs.py:348, in CRS.__init__(self, projparams, **kwargs)
#     346     self._local.crs = projparams
#     347 else:
# --> 348     self._local.crs = _CRS(self.srs)
#
# File pyproj\_crs.pyx:2366, in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: EPSG:1242: (Internal Proj Error: proj_create: crs not found)

# %%
#Creamos la matriz de las distancias del convex hull de las cuencas y los aeropuertos medianos
distanceMatrixKM_cueHull_air=rivers_hulls.set_index('Rivers_name').geometry.apply\
(lambda g: mediumAirports.set_index('Aeropuertos_medianos').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_cueHull_air

# %%
# plotemos
base=rivers_hulls.explore()
#aeropuertos más cercanos
mediumAirports[mediumAirports.Aeropuertos_medianos.isin(mins)].explore(m=base,color='indigo',marker_kwds=dict(radius=10))
#aeropuertos no cercanos
mediumAirports[~mediumAirports.Aeropuertos_medianos.isin(mins)].explore(m=base,color='lightcoral',marker_kwds=dict(radius=5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 base=rivers_hulls.explore()
#       3 #aeropuertos más cercanos
# ----> 4 mediumAirports[mediumAirports.Aeropuertos_medianos.isin(mins)].explore(m=base,color='indigo',marker_kwds=dict(radius=10))
#       5 #aeropuertos no cercanos
#       6 mediumAirports[~mediumAirports.Aeropuertos_medianos.isin(mins)].explore(m=base,color='lightcoral',marker_kwds=dict(radius=5))
#
# NameError: name 'mins' is not defined
